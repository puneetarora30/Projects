# %% [markdown]
# <a href="https://colab.research.google.com/github/puneetarora30/Projects/blob/main/Covid19%20dta%20analysis%20using%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
dataset = pd.read_csv("/content/covid19_Confirmed_dataset.csv")
dataset.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
dataset.drop(["Lat","Long","Province/State"], axis=1,inplace=True)

# %%
dataset.shape
# Out:
# (266, 101)

# %%
dataset.head()
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    Afghanistan        0        0        0        0        0        0
# 1        Albania        0        0        0        0        0        0
# 2        Algeria        0        0        0        0        0        0
# 3        Andorra        0        0        0        0        0        0
# 4         Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# 0     1463     1531     1703     1828     1939     2171
# ...

# %%
dataset_country_aggregated = dataset.groupby("Country/Region").sum()

# %%
dataset_country_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
dataset_country_aggregated.shape
# Out:
# (187, 100)

# %%
dataset_country_aggregated.tail()
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
#                     1/28/20  1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  \
# Country/Region                                          ...
# West Bank and Gaza        0        0        0        0  ...      466      474
# Western Sahara            0        0        0        0  ...        6        6
# Yemen                     0        0        0        0  ...        1        1
# Zambia                    0        0        0        0  ...       70       74
# ...

# %%
dataset_country_aggregated.loc["India"].plot()
dataset_country_aggregated.loc["Spain"].plot()
dataset_country_aggregated.loc["China"].plot()
plt.legend()

# %%
dataset_country_aggregated.loc["China"][:3].plot()
# Out:
# <Axes: >

# %%
print(dataset_country_aggregated.loc["China"].head())
# Out:
# 1/22/20     548
# 1/23/20     643
# 1/24/20     920
# 1/25/20    1406
# 1/26/20    2075
# Name: China, dtype: int64

# %%
print(dataset_country_aggregated.loc["India"].head())
# Out:
# 1/22/20    0
# 1/23/20    0
# 1/24/20    0
# 1/25/20    0
# 1/26/20    0
# Name: India, dtype: int64

# %%
dataset_country_aggregated.loc["China"].empty
# Out:
# False

# %%
dataset_country_aggregated.dtypes
# Out:
# 1/22/20    int64
# 1/23/20    int64
# 1/24/20    int64
# 1/25/20    int64
# 1/26/20    int64
#            ...
# 4/26/20    int64
# 4/27/20    int64
# 4/28/20    int64
# 4/29/20    int64
# 4/30/20    int64
# Length: 100, dtype: object

# %%
dataset_country_aggregated.loc["China"].dtypes
# Out:
# dtype('int64')

# %%
dataset_country_aggregated.loc["China"].diff().plot()
# Out:
# <Axes: >

# %%
dataset_country_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
dataset_country_aggregated.loc["India"].diff().max()
# Out:
# 1893.0

# %%
countries = list (dataset_country_aggregated.index)
max_infection_rates = []
for c in countries:
  max_infection_rates.append(dataset_country_aggregated.loc[c].diff().max())
dataset_country_aggregated["Max_infection_rates"] = max_infection_rates

# %%
dataset_country_aggregated
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
max_corona_data = pd.DataFrame(dataset_country_aggregated["Max_infection_rates"])
max_corona_data
# Out:
#                     Max_infection_rates
# Country/Region
# Afghanistan                       232.0
# Albania                            34.0
# Algeria                           199.0
# Andorra                            43.0
# Angola                              5.0
# ...                                 ...
# West Bank and Gaza                 66.0
# Western Sahara                      4.0
# Yemen                               5.0
# Zambia                              9.0
# Zimbabwe                            8.0
#
# [187 rows x 1 columns]

# %%
#importing the second dataset
happiness_report = pd.read_csv("/content/worldwide_happiness_report.csv")
happiness_report
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
happiness_report.drop(["Overall rank",	"Score", "Generosity","Perceptions of corruption"], axis =1, inplace= True)

# %%
happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness_report.set_index("Country or region", inplace = True)

# %%
happiness_report
# Out:
#                           GDP per capita  Social support  \
# Country or region
# Finland                            1.340           1.587
# Denmark                            1.383           1.573
# Norway                             1.488           1.582
# Iceland                            1.380           1.624
# Netherlands                        1.396           1.522
# ...                                  ...             ...
# Rwanda                             0.359           0.711
# Tanzania                           0.476           0.885
# Afghanistan                        0.350           0.517
# Central African Republic           0.026           0.000
# South Sudan                        0.306           0.575
#
#                           Healthy life expectancy  \
# Country or region
# Finland                                     0.986
# Denmark                                     0.996
# Norway                                      1.028
# ...

# %%
max_corona_data.shape
# Out:
# (187, 1)

# %%
happiness_report.shape
# Out:
# (156, 4)

# %%
data = max_corona_data.join(happiness_report, how= "inner")
data
# Out:
#              Max_infection_rates  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
# ...                          ...             ...             ...
# Venezuela                   29.0           0.960           1.427
# Vietnam                     19.0           0.741           1.346
# Yemen                        5.0           0.287           1.163
# Zambia                       9.0           0.578           1.058
# Zimbabwe                     8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
data.corr()
# Out:
#                               Max_infection_rates  GDP per capita  \
# Max_infection_rates                      1.000000        0.250118
# GDP per capita                           0.250118        1.000000
# Social support                           0.191958        0.759468
# Healthy life expectancy                  0.289263        0.863062
# Freedom to make life choices             0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# Max_infection_rates                 0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# Max_infection_rates                               0.078196
# ...

# %%
data
# Out:
#              Max_infection_rates  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
# ...                          ...             ...             ...
# Venezuela                   29.0           0.960           1.427
# Vietnam                     19.0           0.741           1.346
# Yemen                        5.0           0.287           1.163
# Zambia                       9.0           0.578           1.058
# Zimbabwe                     8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
x = data["GDP per capita"]
y = data["Max_infection_rates"]
sns.scatterplot(data=data, x="GDP per capita", y= "Max_infection_rates")
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Max_infection_rates'>

# %%
#log scaling
data['Log_Max_infection_rates'] = data['Max_infection_rates'].apply(lambda y: np.log(y))
sns.scatterplot(data=data, x="GDP per capita", y= "Log_Max_infection_rates")
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Log_Max_infection_rates'>

# %%
sns.regplot(data=data, x="GDP per capita", y= "Log_Max_infection_rates")
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Log_Max_infection_rates'>

# %%
x = data["Social support"]
y = data["Max_infection_rates"]
data['Log_Max_infection_rates'] = data['Max_infection_rates'].apply(lambda y: np.log(y))
sns.scatterplot(data=data, x="Social support", y= "Log_Max_infection_rates")
# Out:
# <Axes: xlabel='Social support', ylabel='Log_Max_infection_rates'>

# %%
sns.regplot(data=data, x="Social support", y= "Log_Max_infection_rates")
# Out:
# <Axes: xlabel='Social support', ylabel='Log_Max_infection_rates'>

# %%
x = data["Healthy life expectancy"]
y = data["Max_infection_rates"]
data['Log_Max_infection_rates'] = data['Max_infection_rates'].apply(lambda y: np.log(y))
sns.scatterplot(data=data, x="Healthy life expectancy", y= "Log_Max_infection_rates")
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Log_Max_infection_rates'>

# %%
sns.regplot(data=data, x="Healthy life expectancy", y= "Log_Max_infection_rates")
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Log_Max_infection_rates'>

# %%
x = data["Freedom to make life choices"]
y = data["Max_infection_rates"]
data['Log_Max_infection_rates'] = data['Max_infection_rates'].apply(lambda y: np.log(y))
sns.scatterplot(data=data, x="Freedom to make life choices", y= "Log_Max_infection_rates")
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Log_Max_infection_rates'>

# %%
sns.regplot(data=data, x="Freedom to make life choices", y= "Log_Max_infection_rates")
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Log_Max_infection_rates'>
